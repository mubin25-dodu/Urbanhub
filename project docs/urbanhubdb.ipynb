-- %% [markdown]
-- # [UrbanhubDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [UrbanhubDB]    Script Date: 4/21/2026 2:00:51 AM ******/
CREATE DATABASE [UrbanhubDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'UrbanhubDB', FILENAME = N'C:\Users\amimu\UrbanhubDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'UrbanhubDB_log', FILENAME = N'C:\Users\amimu\UrbanhubDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [UrbanhubDB] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [UrbanhubDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [UrbanhubDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [UrbanhubDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [UrbanhubDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [UrbanhubDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [UrbanhubDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [UrbanhubDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [UrbanhubDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [UrbanhubDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [UrbanhubDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [UrbanhubDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [UrbanhubDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [UrbanhubDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [UrbanhubDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [UrbanhubDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [UrbanhubDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [UrbanhubDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [UrbanhubDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [UrbanhubDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [UrbanhubDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [UrbanhubDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [UrbanhubDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [UrbanhubDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [UrbanhubDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [UrbanhubDB] SET  MULTI_USER 
GO
ALTER DATABASE [UrbanhubDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [UrbanhubDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [UrbanhubDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [UrbanhubDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [UrbanhubDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [UrbanhubDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [UrbanhubDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[registration]

-- %%
USE [UrbanhubDB]
GO

-- %%
/****** Object:  Table [dbo].[registration]    Script Date: 4/21/2026 2:00:51 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[registration](
	[rid] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[Email] [varchar](50) NOT NULL,
 CONSTRAINT [PK_registration] PRIMARY KEY CLUSTERED 
(
	[rid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[user]

-- %%
/****** Object:  Table [dbo].[user]    Script Date: 4/21/2026 2:00:51 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[user](
	[uid] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[Email] [varchar](50) NOT NULL,
	[password] [varchar](150) NOT NULL,
	[role] [varchar](50) NOT NULL,
	[address] [varchar](50) NOT NULL,
	[status] [varchar](50) NOT NULL,
	[join_date] [datetime] NOT NULL,
	[vid] [int] NULL,
	[logid] [int] NULL,
 CONSTRAINT [PK_auth] PRIMARY KEY CLUSTERED 
(
	[uid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[verification]

-- %%
/****** Object:  Table [dbo].[verification]    Script Date: 4/21/2026 2:00:51 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[verification](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[uid] [int] NOT NULL,
	[method] [varchar](50) NOT NULL,
	[images] [nvarchar](max) NOT NULL,
	[status] [varchar](50) NOT NULL,
	[applied_on] [datetime] NOT NULL,
	[log_id] [int] NULL,
 CONSTRAINT [PK_verification] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [UrbanhubDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [UrbanhubDB] SET  READ_WRITE 
GO
